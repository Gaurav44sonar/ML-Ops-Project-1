# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://ssonar44477:iza4TwGqljBOvLdX@cluster0.o8bufrp.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# above, either remove your credentials or delete the mongoDB resource bofore pushing it to github.

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
# Uploading data to MongoDB
rec = collection.insert_many(data)

# %%
# Load back data from mongodb

df = pd.DataFrame(list(collection.find()))
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Load back data from mongodb
# ----> 3 df = pd.DataFrame(list(collection.find()))
#       4 df.head(2)
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\synchronous\cursor.py:1285, in Cursor.__next__(self)
#    1284 def __next__(self) -> _DocumentType:
# -> 1285     return self.next()
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\synchronous\cursor.py:1261, in Cursor.next(self)
#    1259 if self._empty:
#    1260     raise StopIteration
# -> 1261 if len(self._data) or self._refresh():
#    1262     return self._data.popleft()
#    1263 else:
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\synchronous\cursor.py:1232, in Cursor._refresh(self)
#    1217     # Exhaust cursors don't send getMore messages.
#    1218     g = self._getmore_class(
#    1219         self._dbname,
#    1220         self._collname,
#    (...)
#    1230         self._comment,
#    1231     )
# -> 1232     self._send_message(g)
#    1234 return len(self._data)
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\synchronous\cursor.py:1104, in Cursor._send_message(self, operation)
#    1101     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1103 try:
# -> 1104     response = client._run_operation(
#    1105         operation, self._unpack_response, address=self._address
#    1106     )
#    1107 except OperationFailure as exc:
#    1108     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1109         # Don't send killCursors because the cursor is already closed.
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:1932, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1922     operation.reset()  # Reset op in case of retry.
#    1923     return server.run_operation(
#    1924         conn,
#    1925         operation,
#    (...)
#    1929         self,
#    1930     )
# -> 1932 return self._retryable_read(
#    1933     _cmd,
#    1934     operation.read_preference,
#    1935     operation.session,  # type: ignore[arg-type]
#    1936     address=address,
#    1937     retryable=isinstance(operation, _Query),
#    1938     operation=operation.name,
#    1939 )
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2041, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2036 # Ensure that the client supports retrying on reads and there is no session in
#    2037 # transaction, otherwise, we will not support retry behavior for this call.
#    2038 retryable = bool(
#    2039     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2040 )
# -> 2041 return self._retry_internal(
#    2042     func,
#    2043     session,
#    2044     None,
#    2045     operation,
#    2046     is_read=True,
#    2047     address=address,
#    2048     read_pref=read_pref,
#    2049     retryable=retryable,
#    2050     operation_id=operation_id,
#    2051 )
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2008, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1971 @_csot.apply
#    1972 def _retry_internal(
#    1973     self,
#    (...)
#    1982     operation_id: Optional[int] = None,
#    1983 ) -> T:
#    1984     """Internal retryable helper for all client transactions.
#    1985
#    1986     :param func: Callback function we want to retry
#    (...)
#    1995     :return: Output of the calling func()
#    1996     """
#    1997     return _ClientConnectionRetryable(
#    1998         mongo_client=self,
#    1999         func=func,
#    2000         bulk=bulk,
#    2001         operation=operation,
#    2002         is_read=is_read,
#    2003         session=session,
#    2004         read_pref=read_pref,
#    2005         address=address,
#    2006         retryable=retryable,
#    2007         operation_id=operation_id,
# -> 2008     ).run()
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2745, in _ClientConnectionRetryable.run(self)
#    2743 self._check_last_error(check_csot=True)
#    2744 try:
# -> 2745     return self._read() if self._is_read else self._write()
#    2746 except ServerSelectionTimeoutError:
#    2747     # The application may think the write was never attempted
#    2748     # if we raise ServerSelectionTimeoutError on the retry
#    2749     # attempt. Raise the original exception instead.
#    2750     self._check_last_error()
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2906, in _ClientConnectionRetryable._read(self)
#    2898 if self._retrying:
#    2899     _debug_log(
#    2900         _COMMAND_LOGGER,
#    2901         message=f"Retrying read attempt number {self._attempt_number}",
#    (...)
#    2904         operationId=self._operation_id,
#    2905     )
# -> 2906 return self._func(self._session, self._server, conn, read_pref)
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:1923, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1916 def _cmd(
#    1917     _session: Optional[ClientSession],
#    1918     server: Server,
#    1919     conn: Connection,
#    1920     read_preference: _ServerMode,
#    1921 ) -> Response:
#    1922     operation.reset()  # Reset op in case of retry.
# -> 1923     return server.run_operation(
#    1924         conn,
#    1925         operation,
#    1926         read_preference,
#    1927         self._event_listeners,
#    1928         unpack_res,
#    1929         self,
#    1930     )
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\synchronous\server.py:208, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res, client)
#     206 else:
#     207     conn.send_message(data, max_doc_size)
# --> 208     reply = conn.receive_message(request_id)
#     210 # Unpack and check for command errors.
#     211 if use_cmd:
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\synchronous\pool.py:470, in Connection.receive_message(self, request_id)
#     468 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     469 except BaseException as error:
# --> 470     self._raise_connection_failure(error)
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\synchronous\pool.py:467, in Connection.receive_message(self, request_id)
#     462 """Receive a raw BSON message or raise ConnectionFailure.
#     463
#     464 If any exception is raised, the socket is closed.
#     465 """
#     466 try:
# --> 467     return receive_message(self, request_id, self.max_message_size)
#     468 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     469 except BaseException as error:
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\network_layer.py:777, in receive_message(conn, request_id, max_message_size)
#     775     data = decompress(receive_data(conn, length - 25, deadline), compressor_id)
#     776 else:
# --> 777     data = receive_data(conn, length - 16, deadline)
#     779 try:
#     780     unpack_reply = _UNPACK_REPLY[op_code]
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\network_layer.py:353, in receive_data(conn, length, deadline)
#     350             short_timeout = _POLL_TIMEOUT
#     351         conn.set_conn_timeout(short_timeout)
# --> 353     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     354 except BLOCKING_IO_ERRORS:
#     355     if conn.cancel_context.cancelled:
#
# File d:\Anaconda\envs\vehicle\lib\site-packages\pymongo\network_layer.py:469, in NetworkingInterface.recv_into(self, buffer)
#     468 def recv_into(self, buffer: bytes) -> int:
# --> 469     return self.conn.recv_into(buffer)
#
# File d:\Anaconda\envs\vehicle\lib\ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File d:\Anaconda\envs\vehicle\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:
